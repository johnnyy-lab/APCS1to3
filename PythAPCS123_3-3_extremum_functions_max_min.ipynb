# %% [markdown]
# # 《PythAPCS123》單元 3-3：極值比較函數（max, min）
#
# **適合對象**：程式設計初學者（完全零基礎） / APCS 扎根第十六部曲
# **對應教材**：吳邦一老師《PythAPCS123：Python 程式設計從 APCS 實作 1 級到 3 級》第 2 章（第 7 頁）
#
# ---
#
# ### 🌟 本單元學習導航地圖
# 在程式設計與演算法中，我們無時無刻不在「比大小」：找出班上最高分、挑選最便宜特價商品、設定安全血量下限...
# 如果每次比大小都要寫落落長的分支判斷（`if a > b and a > c: ...`），程式碼很快就會陷入泥淖。
# 今天我們要請出 Python 內建的兩位「公正大裁判」——**`max()`**（最大值）與 **`min()`**（最小值）！
# 本單元將帶你由淺入深掌握極值三大神技：
# 1. **3-3-1 max() 與 min() 多參數比大小——誰是擂台冠軍與墊底守門員**
# 2. **3-3-2 巢狀合成函數運算——由內而外的同心圓求值順序**
# 3. **3-3-3 三數排序中間值技巧——總和扣除極值的數學巧思**
#
# > 💡 **學習小叮嚀**：每一小節都包含「**說明 ➔ 示範 ➔ 填空 ➔ 練習 ➔ 挑戰**」五個完整步驟，請依序按下每個 Cell 左側的執行按鈕（Play）來動手練習喔！

# %% [markdown]
# ### 🥊 3-3-1 max() 與 min() 多參數比大小——誰是擂台冠軍與墊底守門員
#
# 想像一場熱血的格鬥錦標賽，擂台上站著三位、四位甚至十位選手。主審裁判拿著大聲公宣布：「今天我們要找出全場攻擊力最高的戰士，以及防禦最低的選手！」
# 在 Python 中，你不需要自己辦多場一對一的循環淘汰賽（不用寫一大堆 `if-else`），因為我們有兩位專屬裁判：
# - **`max(arg1, arg2, arg3, ...)`**：最大值裁判！只要把所有競爭者丟給它，它會一眼挑出「最大的數值」！
# - **`min(arg1, arg2, arg3, ...)`**：最小值裁判！不管傳入多少個數字，它專門揪出「最小的數值」！
#
# **運作機制與語法規範：**
# 在 `max()` 與 `min()` 的小括號裡，你可以傳入兩個以上的數值，各數值之間**以逗號 `,` 隔開**。
# 例如：`max(10, 25, 8, 33)` ➔ 裁判會逐一檢視，回傳最大的 **`33`**。
# `min(10, 25, 8, 33)` ➔ 裁判會回傳最小的 **`8`**。
# 它支援正整數、負整數與浮點數混合比較（例如 `min(-5, 3.2, 0)` 會正確回傳 `-5`）。
#
# **常見錯誤陷阱（括號引數守則）：**
# `max()` 與 `min()` 傳入獨立引數時，**至少要有「2 個」以上的引數**！
# 如果你只傳一個數字，例如 `max(42)`，Python 會拋出：
# `TypeError: 'int' object is not iterable`（因為它會以為你想對一個容器做走訪，但 42 只是一個孤單的整數）。比大小一定要有對手，千萬別讓數字孤單上場喔！

# %%
# [2] Code 範例區：展示 max() 與 min() 多參數極值比較

# 範例 1：基本多引數比大小
a = 15
b = 42
c = 28
print(max(a, b, c))     # 印出 42（最大值）
print(min(a, b, c))     # 印出 15（最小值）

# 範例 2：負數與浮點數混合比較
x = -10
y = -3.5
z = 0
print(max(x, y, z))     # 印出 0
print(min(x, y, z))     # 印出 -10

# 範例 3：四個數字比大小
print(max(7, 99, 54, 88))  # 印出 99

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 某射擊遊戲三回合得分分別為 s1 = 88, s2 = 95, s3 = 76。
# 請在空格處填入 max 與 min，分別求出最佳得分 best 與最低得分 worst：
# ==========================================

s1 = 88
s2 = 95
s3 = 76

# 請填入求極值函數：
best = ___(s1, s2, s3)
worst = ___(s1, s2, s3)

print("最高分:", best)   # 預期印出：95
print("最低分:", worst)  # 預期印出：76

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定三個整數 num1, num2, num3。
# 請使用 max() 與 min() 函數，依序在兩行分別印出這三個數的「最大值」與「最小值」。
#
# 【公開測試資料 1】
# num1 = 15, num2 = 42, num3 = 8
# 預期輸出：
# 42
# 8
#
# 【公開測試資料 2】
# num1 = -5, num2 = -12, num3 = 0
# 預期輸出：
# 0
# -12
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

num1 = 15
num2 = 42
num3 = 8
print(max(num1, num2, num3))
print(min(num1, num2, num3))

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 運動會全距計算：
# 四位跳遠選手成績分別為 d1 = 4.85, d2 = 5.12, d3 = 4.60, d4 = 5.30（單位：公尺）。
# 請使用 max() 找出最遠距離，使用 min() 找出最近距離，
# 並計算兩者之差（全距 = 最大值 - 最小值），使用 print() 印出（預期結果應為 0.70 左右）。
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🪆 3-3-2 巢狀合成函數運算——由內而外的同心圓求值順序
#
# 在數學課上，我們常常玩「俄羅斯套娃」：大娃娃肚子裡裝著中娃娃，中娃娃肚子裡又藏著小娃娃。打開娃娃時，我們必須一層一層由外往內剝開；但當電腦在**計算答案**時，順序剛好顛倒過來：**電腦永遠先計算最內層的小娃娃，將算出的答案交給上一層，一路往外推演！**
# 這在數學與電腦科學中，稱為「**合成函數（Composition of Functions）**」或「**巢狀函數（Nested Functions）**」！
#
# **吳邦一老師講義第 7 頁的經典教材範例：**
# 吳老師在講義中展示了一道極具代表性的巢狀算式：
# `x = max(7, 3*5, 5+x*2, y*2)`
# 以及更深層的套娃運算：
# `print( max(1, 3, max(4*y-20, x-3), min(x-8, y-7)) )`
#
# **運作機制拆解：**
# 面對這麼複雜的一長串括號，初學者千萬不要慌張！請像機器人一樣啟動「同心圓雷達」：
# 1. **尋找最內層小括號**：先算裡面的 `max(4*y-20, x-3)` 與 `min(x-8, y-7)`。
# 2. **替換為數值**：把最內層算出的純數字放回原位。
# 3. **推算外層裁判**：外層的 `max(1, 3, 內層結果1, 內層結果2)` 接收到所有數值後，做出最終裁決！
#
# **APCS 解題建議：**
# 雖然 Python 支援無限層套娃，但吳邦一老師在講義中貼心建議：「**算式不要寫得太複雜，可以拆開寫！**」
# 將複雜的內層運算先存入中間變數（例如 `inner_max = max(...)`），能讓程式碼可讀性大幅躍升，除錯時也更容易印出中間數值檢查！

# %%
# [2] Code 範例區：展示巢狀合成函數運作過程

# 範例 1：由內而外的雙層巢狀計算
x = 10
y = 6
# 內層先算：x - 3 = 7，y + 2 = 8
# 外層再算：max(7, 8) = 8
res = max(x - 3, y + 2)
print(res)  # 印出 8

# 範例 2：講義第 7 頁原汁原味巢狀極值範例
ans = max(1, 3, max(4*y - 20, x - 3), min(x - 8, y - 7))
# 4*6 - 20 = 4, x - 3 = 7 -> max(4, 7) = 7
# x - 8 = 2, y - 7 = -1 -> min(2, -1) = -1
# 外層: max(1, 3, 7, -1) = 7
print(ans)  # 印出 7

# 範例 3：拆開寫的好習慣示範
part1 = max(4*y - 20, x - 3)
part2 = min(x - 8, y - 7)
clean_ans = max(1, 3, part1, part2)
print(clean_ans)  # 同樣印出 7，清晰好讀！

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 給定數值 a = 8, b = 15。
# 欲計算巢狀算式：先求 min(a * 2, b)，再與數字 12 取 max()。
# 請在空格處填入 min 與 max，完成由內而外的合成運算：
# ==========================================

a = 8
b = 15

# 請填入極值函數：
nested_result = ___(12, ___(a * 2, b))

print(nested_result)  # a*2=16, min(16, 15)=15, max(12, 15)=15。預期印出：15

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定三個整數 p, q, r。
# 請撰寫一行運算式，計算：max(p + 2, min(q * 3, r - 4))，
# 並使用 print() 印出運算結果。
#
# 【公開測試資料 1】
# p = 5, q = 4, r = 20
# 預期輸出：
# 12
#
# 【公開測試資料 2】
# p = 10, q = 2, r = 15
# 預期輸出：
# 12
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

p = 5
q = 4
r = 20
ans = max(p + 2, min(q * 3, r - 4))
print(ans)

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 數值安全限幅閥（Clamp 演算法）：
# 在遊戲物理中，角色速度 val = 120。
# 遊戲規定：速度不可低於下限 min_limit = 0，且不可高於上限 max_limit = 100。
# 請巧妙利用 min() 與 max() 的雙層巢狀組合：
# 限制 val 在 [min_limit, max_limit] 區間內（公式：min(max_limit, max(min_limit, val))），
# 計算並印出限幅後的合理速度（預期輸出為 100）！
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🏃‍♂️ 3-3-3 三數排序中間值技巧——總和扣除極值的數學巧思
#
# 現在，我們要解鎖數學與演算法思維中最優雅的神技——**「總和扣除極值法」**！
# 假設我們手上有三個數值 $a, b, c$（例如三位選手的百米賽跑成績、三款商品的售價、或是三次段考成績），我們想要將它們「由小到大」依序排好：
# $$low \le mid \le high$$
#
# **剛學程式時的困惑：**
# 初學者此時尚未學過複雜的排序演算法，如果想靠寫判斷式來兩兩比較，不僅程式碼冗長，還容易把自己繞暈。
#
# **數學家傳授的絕妙巧思：**
# 既然只有三個數值：
# 1. **最小值 $low$**：呼叫 `low = min(a, b, c)` 一秒挑出！
# 2. **最大值 $high$**：呼叫 `high = max(a, b, c)` 一秒挑出！
# 3. **最關鍵的中間值 $mid$ 該怎麼找？**
#    仔細觀察：三個數的總和就是 $a + b + c$。
#    如果把三個數的總和，減掉最小的、再減掉最大的，**剩下的那一個，絕對百分之百就是中間值！**
#    $$mid = a + b + c - low - high$$
#
# 完全不需要排序工具，不需要寫任何多重判斷分支，簡潔的三行算式，瞬間將三數由小到大整整齊齊排列出來！這就是演算法思維最迷人的優雅之處！

# %%
# [2] Code 範例區：三數排序中間值技巧示範

# 給定三位選手百米短跑的完賽秒數（秒數越小成績越好）
t1, t2, t3 = 14, 12, 16

# 步驟 1：找出第一名（秒數最小者）
first = min(t1, t2, t3)

# 步驟 2：找出最後一名（秒數最大者）
third = max(t1, t2, t3)

# 步驟 3：總和扣除極值求出第二名（中間值）
second = t1 + t2 + t3 - first - third

# 成果：三位選手秒數由快到慢（由小到大）排列輸出
print(first, second, third)  # 印出 12 14 16

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 小華三次段考的英文成績分別為 score1 = 85, score2 = 92, score3 = 78。
# 請使用總和扣除法求出由小到大排序的成績。
# 請在空格處依序填入 low 與 high，求得中間分數 mid：
# ==========================================

score1, score2, score3 = 85, 92, 78

low = min(score1, score2, score3)
high = max(score1, score2, score3)

# 請填入減去最小與最大的中間值公式：
mid = score1 + score2 + score3 - ___ - ___

print(low, mid, high)  # 預期印出：78 85 92

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 文具店展示架上有三款筆記本，價格分別為 price1, price2, price3。
# 請使用 min()、max() 與「總和扣除極值」的數學方法，
# 求出由便宜到昂貴（由小到大）的三個價格，
# 並使用 print() 在同一行依序印出它們（以空白間隔）。
#
# 【公開測試資料 1】
# price1 = 350, price2 = 120, price3 = 280
# 預期輸出：
# 120 280 350
#
# 【公開測試資料 2】
# price1 = 50, price2 = 90, price3 = 60
# 預期輸出：
# 50 60 90
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

price1 = 350
price2 = 120
price3 = 280
low = min(price1, price2, price3)
high = max(price1, price2, price3)
mid = price1 + price2 + price3 - low - high
print(low, mid, high)

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 商場週年慶「買三件特惠促銷」結帳機：
# 顧客挑選了三件衣服，標價分別為 item1 = 320, item2 = 180, item3 = 450。
# 促銷活動規則如下：
# 1. 三件中「最便宜的一件」可享半價（使用整數除法 // 2 計算半價金額）。
# 2. 另外兩件以原價計費。
# 請運用本單元學到的技巧完成：
# - 使用 min() 找出最便宜的一件價格 cheapest。
# - 使用總和扣除法（item1 + item2 + item3 - cheapest）直接算出另外兩件的原價總和 other_sum。
# - 計算結帳實付總額 total_pay = other_sum + (cheapest // 2)。
# - 最後使用 print(total_pay) 印出最終結帳金額！
# （提示：320 + 180 + 450 = 950；最便宜是 180，半價 90；另兩件 770；結帳總額為 860 元）
# ==========================================
# 請在下方撰寫你的程式碼：

item1 = 320
item2 = 180
item3 = 450

cheapest = min(item1, item2, item3)
other_sum = item1 + item2 + item3 - cheapest
total_pay = other_sum + (cheapest // 2)
print(total_pay)

# %% [markdown]
# ---
# ### 🏆 恭喜完成單元 3-3：極值裁判大師徽章！
#
# 太棒了！今天你在數值比較的世界裡，掌握了高階競賽選手必備的極值屠龍技：
# 1. **多參數 `max()` 與 `min()`**：隨意傳入任意多個數字，一秒挑出最強冠軍與墊底數值。
# 2. **巢狀合成函數同心圓**：搞懂括號由內而外的計算本質，看懂講義第 7 頁俄羅斯套娃算式。
# 3. **三數排序中間值技巧**：掌握 `mid = a + b + c - low - high`，不用排序演算法也能三行排好三個數值！
#
# 👉 **下一關預告**：在 **單元 3-4** 中，我們要來學習「**絕對值計算（abs）**」，探索數線上的無向距離守護者，學習如何直接求出兩點差距、確保差值恆為正數！我們下一關見！
