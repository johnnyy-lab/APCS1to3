# %% [markdown]
# # 《PythAPCS123》單元 8-3：串列常用內建方法（append, pop, insert 等）
#
# **適合對象**：程式設計初學者（完全零基礎） / APCS 扎根第四十七部曲（第八章串列容器第三部曲）
# **對應教材**：吳邦一老師《PythAPCS123：Python 程式設計從 APCS 實作 1 級到 3 級》第 12 章（第 44 頁）、第 17.3 節（第 79–81 頁）
#
# ---
#
# ### 🌟 本單元學習導航地圖
# 在單元 8-1 與 8-2 中，我們學會了靜態建立串列以及用切片進行區間操作。
# 然而，在真正的程式開發中，資料往往是「動態湧入」的：
# - 「*使用者不知道總共會輸入幾個數字，每輸入一個數字就得立刻存進串列！*」
# - 「*排隊隊伍中，最後一個人辦完事離開了（彈出）！*」
# - 「*VIP 會員拿著優先號碼牌，硬生生插隊到隊伍正中央！*」
# - 「*名單中有人退選，我們需要精確把他的名字從名冊中刪除！*」
#
# 如果只能靠切片硬湊，邏輯會顯得不夠直觀。為此，Python 為串列量身打造了極為強悍的**「五大內建方法（Built-in Methods）」**！
# 這些方法就像是串列自帶的機械手臂，能夠隨心所欲地在尾端追加、在任意位置插入、將元素彈出或就地反轉。
#
# 本單元精心規劃了五大循序漸進的精華修練關卡：
# 1. **8-3-1 尾端動態追加：`.append(x)` 方法與迴圈收集模式**
# 2. **8-3-2 元素彈出與提取：`.pop()` 尾端彈出與指定索引彈出**
# 3. **8-3-3 指定位置插隊：`.insert(index, x)` 方法**
# 4. **8-3-4 指定數值精確刪除：`.remove(x)` 方法與 `ValueError` 防禦**
# 5. **8-3-5 串列就地反轉：`.reverse()` 方法與原串列直接翻轉**
#
# > 💡 **學習小叮嚀（嚴格零提前依賴）**：本單元**嚴格禁止使用任何尚未正式教授的語法**！包含：串列統計函數（如 `sum()`，8-4 節才會學）、進階線性搜尋（8-5 節）、列表生成式（8-7 節）或自訂函數（`def`）。所有動態增刪改查完全基於此五大核心方法。請跟隨標準五步驟（**說明 ➔ 範例 ➔ 填空 ➔ 練習 ➔ 挑戰**），掌握動態管理串列資料的最高心法！

# %% [markdown]
# ### 📥 8-3-1 尾端動態追加：.append(x) 方法與迴圈收集模式
#
# **生活比喻：排隊隊伍來了新客人與購物車丟入新戰利品**
# 想像你在超市推著一台原本空空如也的購物車 `cart = []`。當你逛到零食區看到一包洋芋片，你順手把它「放進購物車尾端」；走到飲料區看到一瓶可樂，你又把它「放進購物車尾端」。每拿起一樣商品，購物車就多裝一樣，完全不需要事先預測到底會買幾件！
# 在 Python 串列中，擔任這個「丟進尾端」動作的超級核心方法，就是 **`.append(x)`**！
#
# **底層運作機制：O(1) 均攤極速追加**
# 語法：`a.append(x)`
# - 會直接把元素 `x` 接在串列的最末端，串列長度 `len(a)` 自動加 1！
# - **就地修改特性**：`.append()` 直接修改原串列，它的**回傳值是 `None`**！因此**千萬不能寫 `a = a.append(x)`** ❌，否則 `a` 會瞬間變成 `None` 而把原本的資料徹底摧毀！
#
# **競賽最核心模式：空串列初始化 + 迴圈動態收集**
# 在遇到未知或動態數據時，標準模板如下：
# ```python
# numbers = []  # 1. 建立空串列
# for i in range(5):
#     x = int(input())  # 2. 讀入新數值
#     numbers.append(x)  # 3. 動態收納進尾端
# ```
#
# **常見錯誤陷阱：一次 append 多個元素被當成單一容器塞入**
# 若執行 `a.append([1, 2])`，Python 會把 `[1, 2]` 整包當成「單一一個子串列」塞在尾端，形成巢狀串列，而不是扁平地加上兩個數字！若要單獨加，必須分次呼叫。
#
# **APCS 考試實務建議：**
# `.append()` 是所有動態資料收集的起點，在 APCS 實作題中，從過濾特定條件資料到讀取多行測資，幾乎 100% 的題目都會使用 `.append()`，必須熟練到化為直覺。

# %%
# [2] Code 範例區：展示 .append() 方法的尾端動態追加效果
# 說明：從空串列出發，逐次追加元素，並展示迴圈收集數值。

# 步驟 1：建立空購物清單
cart = []
print("初始購物車:", cart)

# 步驟 2：逐步追加商品
cart.append("Apple")
cart.append("Banana")
cart.append("Milk")
print("追加三項商品後:", cart)
print("目前商品總件數:", len(cart))

# 步驟 3：迴圈收集偶數範例
evens = []
for i in range(1, 6):
    evens.append(i * 2)
print("迴圈收集的偶數串列:", evens)

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 請呼叫 append 方法，依序將數字 100 與 200 追加到空串列 a 中，
# 使其最終包含 [100, 200]！
# ==========================================

a = []

# 請呼叫 append 方法：
a.___(100)
a.___(200)

# 驗證區（請勿更動下方代碼）
if a == [100, 200]:
    print("恭喜答對！成功使用 .append() 完成動態收納！")
else:
    print("檢查看看方法名稱是否填入 append 喔！")

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 正整數及格名單過濾收集器：
# 程式第一行輸入一個整數 n（代表接下來有 n 筆成績）。
# 接下來有 n 行，每行輸入一個學生分數 score（整數）。
# 請建立一個空串列 passed_list = []。
# 在讀取過程中，若 score >= 60，使用 .append(score) 將及格分數收納進串列中！
# 讀取完畢後，使用 print(*passed_list) 一行印出所有及格分數。
#
# 【公開測試資料 1】
# 輸入：
# 4
# 85
# 42
# 90
# 58
# 預期輸出：
# 85 90
#
# 【公開測試資料 2】
# 輸入：
# 3
# 70
# 60
# 100
# 預期輸出：
# 70 60 100
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# 3 的倍數收集生成器：
# 程式輸入一個正整數 n（3 <= n <= 30）。
# 請使用 for 迴圈走訪數字 1 到 n，
# 若當前數字為 3 的倍數（i % 3 == 0），使用 .append(i) 收納進串列 multiples 中。
# 最後以 print(*multiples) 印出所有被收集的倍數。
# 例如輸入：
# 10
# 輸出：
# 3 6 9
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 📤 8-3-2 元素彈出與提取：.pop() 尾端彈出與指定索引彈出
#
# **生活比喻：洋芋片筒的彈出與排隊叫號**
# 想像一筒品客洋芋片，因為筒身開口在頂端，你每次伸手進去拿，最先拿到的永遠是「最上面那一片」（最後放進去的那一片）。這在資料結構中被稱為「堆疊（Stack，後進先出）」。
# 又或者在銀行櫃台，叫號機喊：「請 1 號顧客到櫃台！」，排在最前端的人被請出隊伍，這叫做「佇列（Queue，先進先出）」。
# 在 Python 串列中，能同時完美勝任這兩種角色的一手遮天神技，就是 **`.pop()`**！
#
# **底層運作機制：移除並回傳被刪除的寶物**
# `.pop()` 與一般刪除最關鍵的不同在於：**它會把被刪除的那個元素「親手交到你手上（回傳）」**！
# 1. **預設尾端彈出：`item = a.pop()`**
#    - 括號不填參數時，預設移除並回傳**最後一個元素（相當於 a.pop(-1)）**！
#    - 速度極快，為 $O(1)$ 常數時間！
# 2. **指定索引彈出：`item = a.pop(index)`**
#    - 例如 `item = a.pop(0)`：移除並回傳**第一個元素**，後方所有元素自動往前遞補一格！
#    - 範例：
#      `cards = ["A", "B", "C"]`
#      `taken = cards.pop()`  # taken 拿到 "C"，cards 剩下 ["A", "B"]！
#
# **常見錯誤陷阱：對空串列使用 pop() 會引發崩潰**
# 若串列已經空空如也，你還貪心地呼叫 `a.pop()` ❌，Python 直譯器會立刻報錯：
# **`IndexError: pop from empty list`**！
# 因此在迴圈中使用 pop 前，務必以 `while len(a) > 0:` 或 `while a:` 進行安全防護。
#
# **APCS 考試實務建議：**
# 在模擬遊戲（如紙牌出牌、倒水模擬、字元堆疊比對）中，`.pop()` 是一邊刪除、一邊拿取數據進行即時運算的核心標準方法。

# %%
# [2] Code 範例區：展示 .pop() 尾端彈出與指定索引彈出的效果
# 說明：觀察被彈出元素的回傳值，以及原串列的長度縮減。

stack = ["Plate 1", "Plate 2", "Plate 3"]
print("原本盤子堆疊:", stack)

# 1. 預設尾端彈出 (拿走最上面的盤子)
top_plate = stack.pop()
print("拿走的盤子:", top_plate)
print("剩餘盤子  :", stack)

# 2. 指定索引彈出 (pop(0) 拿走最底下的盤子)
bottom_plate = stack.pop(0)
print("拿走最底盤子:", bottom_plate)
print("最終剩餘盤子:", stack)

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 請呼叫 pop 方法將串列 nums = [10, 20, 30] 最尾端的 30 彈出，
# 並將其存入變數 last_item 中！
# ==========================================

nums = [10, 20, 30]

# 請呼叫 pop() 彈出末端元素：
last_item = nums.___()

# 驗證區（請勿更動下方代碼）
if last_item == 30 and nums == [10, 20]:
    print("恭喜答對！成功使用 .pop() 提取末尾元素！")
else:
    print("檢查看看方法名稱是否為 pop 喔！")

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 堆疊出牌模擬器：
# 初始手牌串列 cards = ["Spade A", "Heart K", "Diamond Q"]。
# 玩家依序執行兩次出牌（每次都出最右側最後摸進來的那張牌，即 cards.pop()）。
# 請依序印出：
# Play card: [第1次出的牌]
# Play card: [第2次出的牌]
# Remaining: [最後剩餘的牌 (使用 print(*cards))]
#
# 【公開測試資料 1】
# 輸入：（無外部輸入，直接以題幹 cards 執行）
# 預期輸出：
# Play card: Diamond Q
# Play card: Heart K
# Remaining: Spade A
#
# 【公開測試資料 2】
# 若 cards 改為 ["Card 1", "Card 2", "Card 3"]
# 預期輸出：
# Play card: Card 3
# Play card: Card 2
# Remaining: Card 1
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# 排隊叫號隊列模擬（FIFO 佇列模擬器）：
# 某診所目前排隊串列 queue = ["Patient 1", "Patient 2", "Patient 3"]。
# 程式將輸入一個整數 k（1 <= k <= 3，代表看診人數）。
# 請使用 for 迴圈或 while 迴圈呼叫 k 次 queue.pop(0)（叫號並移出最前面的病患），
# 每叫到一位，印出：Served: [病患代號]
# 最後若隊伍還有剩餘病患，印出剩餘串列，若全數看診完畢則印出 "ALL SERVED!"。
# 例如 k = 2，輸出：
# Served: Patient 1
# Served: Patient 2
# Remaining: ['Patient 3']
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 📌 8-3-3 指定位置插隊：.insert(index, x) 方法
#
# **生活比喻：隊伍插隊與活頁筆記本插入新頁**
# 想像在排隊隊伍中，原本 0 號和 1 號站得好好的。這時一位拿著特權手環的 VIP 貴賓直接走向「1 號」的位置站在那裡！原本的 1 號以及他身後的所有人，非常有禮貌地全部「向後退一步」讓出空位。
# 在 Python 串列中，能夠在任意指定的抽屜位置「強制插入」新元素的方法，就是 **`.insert()`**！
#
# **底層運作機制與參數順序**
# 語法：`a.insert(index, value)`
# - 第一個參數 `index`：**要插入的目標索引位置**！
# - 第二個參數 `value`：**要插入的寶物內容**！
# - 運作效果：原本位於 `index` 及其之後的所有舊元素，索引會自動全體加 1 向後順移，串列長度 `len(a)` 自動加 1！
# - 範例：
#   `ranks = ["A", "C"]`
#   `ranks.insert(1, "B")`  # 在索引 1 插入 "B"
#   結果：`["A", "B", "C"]`！原本的 "C" 被推到了索引 2！
#
# **首尾插入技巧：**
# - 最開頭插入（隊頭插隊）：`a.insert(0, x)`
# - 最末尾插入：`a.insert(len(a), x)`（等價於 `a.append(x)`）。
#
# **常見錯誤陷阱：參數順序搞反！**
# 初學者最容易犯的錯誤就是把位置與內容填反：寫成 `a.insert("B", 1)` ❌！
# 這會引發 `TypeError: 'str' object cannot be interpreted as an integer`！請牢記：**先給位置號碼牌（int），再給放進去的東西**。
#
# **APCS 考試實務建議：**
# 在模擬遊戲或資料維護中，若需要維持串列嚴格的特定順序，在指定位置插入新資料時，`.insert()` 能讓你無需手動撰寫元素搬移迴圈。

# %%
# [2] Code 範例區：展示 .insert(index, value) 的指定位置插入效果
# 說明：觀察在隊首 (索引 0) 與隊伍中間插入時，其餘元素的自動後移。

queue = ["Bob", "David"]
print("原本隊伍:", queue)

# 1. 在最開頭插入 Alice (索引 0)
queue.insert(0, "Alice")
print("隊首插入 Alice 後:", queue)

# 2. 在中間插入 Charlie (索引 2)
queue.insert(2, "Charlie")
print("中間插入 Charlie 後:", queue)

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 請觀察串列 nums = [10, 30]，
# 請呼叫 insert 方法，在索引 1 的位置插入缺少的 20，
# 使其完整變成 [10, 20, 30]！
# ==========================================

nums = [10, 30]

# 請填入方法名稱與參數（位置, 內容）：
nums.___(1, 20)

# 驗證區（請勿更動下方代碼）
if nums == [10, 20, 30]:
    print("恭喜答對！成功使用 .insert(1, 20) 完成中間插入！")
else:
    print("檢查看看方法名稱是否為 insert 喔！")

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 哨兵隊長加頂儀：
# 程式將輸入 3 個整數存入串列 a 中。
# 演算法需要建立一個「哨兵開頭」：請在最開頭（索引 0）插入一個數值 0（使用 a.insert(0, 0)）！
# 請印出加入哨兵後的串列。
#
# 【公開測試資料 1】
# 輸入：
# 5
# 10
# 15
# 預期輸出：
# [0, 5, 10, 15]
#
# 【公開測試資料 2】
# 輸入：
# 99
# 88
# 77
# 預期輸出：
# [0, 99, 88, 77]
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# 保持遞增之排序插入模擬（插入排序核心微步）：
# 串列 sorted_list = [10, 20, 30, 40]（已由小到大排好）。
# 程式輸入一個整數 x（例如 25）。
# 請找出第一個大於 x 的元素位置 i，並使用 sorted_list.insert(i, x) 將 x 插入該處；
# 若所有元素都小於 x，則直接 append 到尾端！
# 插入後依然維持遞增排序，以 print(*sorted_list) 印出結果！
# 例如輸入：25
# 輸出：10 20 25 30 40
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🎯 8-3-4 指定數值精確刪除：.remove(x) 方法與 ValueError 防禦
#
# **生活比喻：除名名冊與根據姓名抓捕犯人**
# 在公會成員名冊中，有一位隊員申請退會。公會會長不需要知道他是坐在幾號椅子上，他只看名字：「誰叫 John？找到名冊上的 John，直接畫線除名！」。
# 在 Python 串列中，如果我們**只知道要刪除的數值內容，不知道它的索引號碼**，專屬的精準除名神技就是 **`.remove(x)`**！
#
# **底層運作機制與只刪除第一個匹配項**
# 語法：`a.remove(value)`
# - 直譯器會從左到右掃描串列，找到**第一個剛好等於 `value` 的元素**，將其徹底拔除！
# - 後方的所有元素自動向前遞補，串列長度減 1。
# - **重要特性：只刪除第一個！**
#   若 `a = [1, 2, 2, 3]`，執行 `a.remove(2)` 後，串列變成 `[1, 2, 3]`（只有第一個 2 被刪掉，第二個 2 依然健在！）。
#
# **致命陷阱：數值不存在會直接引發 ValueError 崩潰！**
# 如果串列裡根本沒有這個值，你卻執行 `a.remove(99)` ❌，Python 會立刻當場崩潰：
# **`ValueError: list.remove(x): x not in list`**
# 因此，在呼叫 `.remove()` 之前，**絕對安全的防禦型寫法必須搭配 `in` 檢查**：
# ```python
# if value in a:
#     a.remove(value)
# ```
#
# **APCS 考試實務建議：**
# 在購物退貨模擬、消消樂遊戲或特定數值剔除題型中，`.remove()` 搭配 `if x in a:` 能徹底消除 `ValueError` 導致的 RE 判定風險。

# %%
# [2] Code 範例區：展示 .remove(x) 指定數值刪除與安全防禦
# 說明：觀察只刪除第一個匹配項的特性，以及搭配 if in 的安全防範。

items = ["Sword", "Shield", "Potion", "Shield"]
print("原本道具列表:", items)

# 1. 刪除指定道具 (只會刪除左邊第一面 Shield)
items.remove("Shield")
print("刪除一面盾牌後:", items)

# 2. 安全防禦：先用 in 檢查，避免 ValueError
target = "Dragon Bow"
if target in items:
    items.remove(target)
else:
    print("背包中無此道具: '" + target + "'，安全略過！")

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 請呼叫 remove 方法，從名冊 members = ["Alice", "Bob", "Charlie"] 中
# 將 "Bob" 移除！
# ==========================================

members = ["Alice", "Bob", "Charlie"]

# 請呼叫 remove 方法：
members.___("Bob")

# 驗證區（請勿更動下方代碼）
if members == ["Alice", "Charlie"]:
    print("恭喜答對！成功使用 .remove('Bob') 移除指定元素！")
else:
    print("檢查看看方法名稱是否填入 remove 喔！")

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 瑕疵品批號剔除器：
# 初始批號串列 batches = [101, 202, 303, 404, 505]。
# 程式將輸入一個整數 defect_batch（瑕疵品編號）。
# 請使用 if defect_batch in batches: 安全檢查：
# - 若存在，呼叫 batches.remove(defect_batch) 並以 print(*batches) 印出剩餘批號！
# - 若不存在，印出 "NOT FOUND"。
#
# 【公開測試資料 1】
# 輸入：
# 303
# 預期輸出：
# 101 202 404 505
#
# 【公開測試資料 2】
# 輸入：
# 999
# 預期輸出：
# NOT FOUND
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# 重複值全數連根拔起（刪除所有特定數值）：
# 宣告串列 a = [1, 2, 3, 2, 4, 2, 5]。
# 題目要求將裡面「所有出現的 2」全部徹底刪除，一個都不留！
# 提示：可搭配 while 2 in a: 迴圈反覆呼叫 a.remove(2)！
# 刪除完畢後，印出乾淨的串列。
# 最終預期輸出：
# [1, 3, 4, 5]
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🔁 8-3-5 串列就地反轉：.reverse() 方法與切片對比
#
# **生活比喻：原地向後轉走齊步 vs 另外照鏡子印照片**
# 在國慶閱兵大典上，教官一聲令下：「全體都有，向後轉！」，原本排在最後面的班長直接變成第一排，整支隊伍**就在原地**直接調頭，沒有花費任何額外的操場空間！
# 在單元 8-2 中，我們學過切片反轉 `a[::-1]`；而 Python 為串列準備的另一個原地反轉大招就是 **`.reverse()`**！
#
# **底層運作機制與巨大差別對比**
# 這兩者在演算法面試與競賽中是高頻考點，請務必分清：
# 1. **`a[::-1]`（切片反轉）**：
#    - **不修改原串列**！
#    - 會在記憶體中消耗額外空間，**產出一個全新的獨立新串列**！
# 2. **`a.reverse()`（就地反轉方法）**：
#    - **直接修改原串列本身**（In-place）！
#    - 不佔用任何額外記憶體，空間複雜度是極致的 $O(1)$！
#    - **重要致命陷阱**：與 `.append()` 一樣，`.reverse()` 是就地操作，它的**回傳值是 `None`**！
#      千萬不能寫 `a = a.reverse()` ❌，否則 `a` 會瞬間變成 `None`！正確寫法是單獨一行呼叫：`a.reverse()`！
#
# **APCS 考試實務建議：**
# 當串列規模高達數十萬筆、且後續不需要再用到原順序時，使用 `a.reverse()` 能節省大量記憶體開銷，防止在大數據測資下引發記憶體超限（MLE）。

# %%
# [2] Code 範例區：展示 .reverse() 方法的原地修改效果與回傳值注意
# 說明：觀察原串列身分證 id 不變的原地翻轉，並警惕 None 回傳值。

nums = [1, 2, 3, 4, 5]
print("原本串列:", nums)
orig_id = id(nums)

# 就地反轉
nums.reverse()
print("反轉之後:", nums)
print("記憶體位址完全不變:", id(nums) == orig_id)

# 警惕：千萬不要賦值給變數
# 若寫 x = nums.reverse()，x 的值會是 None！

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 請呼叫 reverse 方法，將串列 letters = ["A", "B", "C"]
# 就地反轉為 ["C", "B", "A"]！
# ==========================================

letters = ["A", "B", "C"]

# 請呼叫 reverse 方法（單獨一行）：
letters.___()

# 驗證區（請勿更動下方代碼）
if letters == ["C", "B", "A"]:
    print("恭喜答對！成功呼叫 .reverse() 完成原地反轉！")
else:
    print("檢查看看方法名稱是否為 reverse 喔！")

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 逆序倒數就地計時器：
# 程式連續讀入 4 個整數存入串列 countdown 中。
# 請使用 countdown.reverse() 將串列進行原地反轉。
# 反轉後，使用 print(*countdown) 一行印出倒數數列！
#
# 【公開測試資料 1】
# 輸入：
# 1
# 2
# 3
# 4
# 預期輸出：
# 4 3 2 1
#
# 【公開測試資料 2】
# 輸入：
# 10
# 20
# 30
# 40
# 預期輸出：
# 40 30 20 10
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# 雙端操作模擬器（雙向隊列微體驗）：
# 宣告串列 buffer = [10, 20, 30]。
# 模擬以下四步操作：
# 1. 尾端追加 40（.append(40)）
# 2. 最前端插入 0（.insert(0, 0)）
# 3. 彈出並移除最後一個元素（.pop()）
# 4. 將串列就地反轉（.reverse()）
# 請在執行完四步後，以 print(*buffer) 印出最終串列！
# 預期輸出：
# 30 20 10 0
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ---
# ### 🏆 恭喜完成單元 8-3，榮獲「串列機械操盤大師」榮譽徽章！
#
# 太強悍了！在單元 8-3 中，各位自學冒險者成功掌握了串列最靈魂的五大內建方法：
# 1. **尾端動態追加（`.append()`）**：解鎖空串列起手與迴圈收集數據的競技標準模板！
# 2. **元素彈出提取（`.pop()`）**：兼顧堆疊（LIFO）與佇列（FIFO），實現一邊刪除一邊拿取回傳值的高級操作！
# 3. **指定位置插隊（`.insert()`）**：精熟先給位置、再給物件的語法規範，輕鬆搞定哨兵插入！
# 4. **指定數值刪除（`.remove()`）**：掌握除名第一個匹配項的特性，並學會以 `if x in a:` 防禦 `ValueError` 崩潰！
# 5. **就地反轉神技（`.reverse()`）**：深刻理解與切片反轉的本質區別，以 $O(1)$ 常數空間原地翻轉巨大串列！
#
# ---
#
# ### 🗺️ 第八章學習進度追蹤（3 / 7 勢不可擋！）：
# - [x] **8.1 串列建立、正負索引與解包輸出（print(*a)）**（[ ] 建立、Mutable、[0]*n、print(*a)）
# - [x] **8.2 串列切片語法與切片賦值**（區間抽取、就地切片替換與清空）
# - [x] **8.3 串列常用內建方法（append, pop, insert 等）**（動態增刪查改、就地反轉）
# - [ ] **8.4 串列統計與極值運算（sum, max, min, len）**（加總、平均、極值與空串列防禦）
# - [ ] **8.5 串列走訪與成員查詢（for, index, in）**（元素走訪、索引更新與線性搜尋）
# - [ ] **8.6 串列參照與淺拷貝（copy, [:]）**（指標參照陷阱與獨立副本複製）
# - [ ] **8.7 列表生成式與動態輸入（List Comprehension）**（單行多數值讀取與條件生成式）
#
# ---
#
# 👉 **下節預告：【8-4 串列統計與極值運算（sum, max, min, len）】**
# 當串列收集了上千筆數字後，我們該如何一秒算出全體總和、平均值、全班最高分與最低分？
# 免寫迴圈的四大天王函數：`len()`、`sum()`、`max()`、`min()` 即將震撼登場！
# 同時我們將揭示空串列求極值引發的重大崩潰地雷與避坑心法，讓我們繼續乘勝追擊！
