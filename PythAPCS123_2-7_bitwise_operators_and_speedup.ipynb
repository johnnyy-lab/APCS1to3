# %% [markdown]
# # 《PythAPCS123》單元 2-7：位元運算子與解題加速
#
# **適合對象**：國中一年級程式設計初學者（零基礎） / APCS 扎根第十三部曲（第二章完結大封頂！）
# **對應教材**：吳邦一老師《PythAPCS123：Python 程式設計從 APCS 實作 1 級到 3 級》第 17.1 節 位元運算（第 78 頁）
#
# ---
#
# ### 🌟 本單元學習導航地圖
# 在上一節中，我們學會了用 `0b` 寫出電腦的二進位母語。今天我們要正式解鎖直接操控這一個個二進位 0 與 1 的「**五大超光速位元運算子（Bitwise Operators）**」！
# 它們是競技程式中專門用來打破執行時間限制（TLE）的究極加速秘法：
# 1. **2-7-1 位元 AND（&）與超光速奇偶判斷（x & 1）**
# 2. **2-7-2 位元 OR（|）與狀態開關強制啟用**
# 3. **2-7-3 位元 XOR（^）與開關翻轉／相同自消魔法**
# 4. **2-7-4 位元左移（<<）與右移（>>）——二進位滑梯與乘除倍增**
#
# > 💡 **學習小叮嚀**：每一小節都包含「**說明 ➔ 示範 ➔ 填空 ➔ 練習 ➔ 挑戰**」五個完整步驟，請依序按下每個 Cell 左側的執行按鈕（Play）來動手練習喔！

# %% [markdown]
# ### ⚡ 2-7-1 位元 AND（&）與超光速奇偶判斷（x & 1）
#
# 在日常生活裡，如果我們要核驗兩把鑰匙才能開門，必須兩把都吻合才行。這就是「**位元 AND 運算子 `&`（Bitwise AND）**」的運作機制！
#
# **位元 AND 的運算真值表**：
# 電腦會把兩個數字轉成二進位，由右至左「一個位元一個位元」進行垂直對齊比對：
# * `1 & 1` $\rightarrow$ **`1`**（只有雙方都是 1，結果才是 1！）
# * `1 & 0` $\rightarrow$ **`0`**
# * `0 & 1` $\rightarrow$ **`0`**
# * `0 & 0` $\rightarrow$ **`0`**
# 例如：`0b1010 & 0b1100`，只有第 4 位元都是 1，所以結果是 `0b1000`（十進位 8）！
#
# **🚀 吳邦一老師講義第 78 頁傳授的絕殺秘技：`x & 1` 取代模除奇偶判斷！**
# 在單元 2-3 中，我們學過用 `x % 2` 算餘數來判斷奇數偶數。但在電腦硬體層面，除法運算需要消耗幾十個 CPU 時脈週期；而**位元運算 `&` 只需要「1 個時脈週期」**！
#
# **為什麼 `x & 1` 可以一秒判斷奇偶？**
# 在二進位中，所有的權重都是 2 的倍數（2, 4, 8, 16... 全部都是偶數！），**全天下只有最右邊的第一位（$2^0 = 1$）能決定奇偶**！
# * 數字 1 的二進位就是 `...0001`。
# * 當任何數字 `x` 和 `1` 做 AND 運算時：前面所有偶數位元通通會被乘以 0 抹殺掉，**只留下最右邊的那 1 位**！
#   * 如果最右邊是 1（奇數）：`x & 1` 算出來必定是 **`1`**！
#   * 如果最右邊是 0（偶數）：`x & 1` 算出來必定是 **`0`**！
#
# 在 APCS 百萬次大數據走訪測資中，把 `x % 2 == 1` 改寫成 `x & 1`，能大幅飆高執行速度，徹底遠離超時 TLE 惡夢！

# %%
# [2] Code 範例區：展示位元 AND（&）與 x & 1 極速奇偶判斷
# 範例 1：兩個二進位數進行逐位元 AND 比對
a = 0b1010  # 十進位 10
b = 0b1100  # 十進位 12
c = a & b   # 只有最高位都是 1，結果為 0b1000
print(c)    # 印出 8
print(bin(c)) # 印出 '0b1000'

# 範例 2：APCS 絕殺加速技——x & 1 判斷奇偶數
even_num = 42
odd_num = 99
print(even_num & 1)  # 印出 0（偶數最末位是 0）
print(odd_num & 1)   # 印出 1（奇數最末位是 1）

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 想要使用極速位元運算子，檢驗 score = 87 是否為奇數。
# 請在空格處填入位元 AND 運算子 & 與數字 1：
# ==========================================

score = 87

# 奇偶檢驗：score & 1
is_odd = score ___
print(is_odd)  # 預期印出 1（代表 87 是奇數）

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定一個整數 num_check。
# 請使用位元 AND 運算子 num_check & 1 計算其最末位元數值，
# 並使用 print() 印出計算結果（奇數應輸出 1，偶數應輸出 0）。
#
# 【公開測試資料 1】
# num_check = 128
# 預期輸出：
# 0
#
# 【公開測試資料 2】
# num_check = 255
# 預期輸出：
# 1
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 遊戲中的升級機制：
# 玩家等級為 level = 16。
# 請使用 (level & 1) 判斷：
# 當 (level & 1) 等於 0 時代表偶數等級，可獲得雙倍獎勵（level * 2）；
# 否則獲得一般獎勵（level）。
# 請設計算式求出獎勵點數並印出（預期為 32）！
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🔌 2-7-2 位元 OR（|）與狀態開關強制啟用
#
# 接下來我們要認識第二位成員——「**位元 OR 運算子 `|`（Bitwise OR，鍵盤 Shift + 反斜線 \ 鍵）**」！
#
# 你可以把位元 OR 想像成國小自然課學過的「**並聯電路開關**」：
# 只要兩條電路中「**有任何一條通電（為 1）**」，燈泡就會立刻亮起來！只有在兩條都斷電（都是 0）時，燈泡才會熄滅。
#
# **位元 OR 的運算真值表**：
# * `1 | 1` $\rightarrow$ **`1`**
# * `1 | 0` $\rightarrow$ **`1`**
# * `0 | 1` $\rightarrow$ **`1`**
# * `0 | 0` $\rightarrow$ **`0`**（只有雙方都是 0，結果才是 0！）
#
# 例如：`0b1010 | 0b0101`，每一位剛好都各有 1，合併起來就變成了全開的 `0b1111`（十進位 15）！
#
# **🎛️ 狀態遮罩核心神技：點亮開關（Set Bit）**：
# 在競技遊戲與 APCS 題目中，假設勇者當前的狀態只有護盾：`status = 0b0100`（第 3 位元是 1）。
# 現在勇者喝下了加速藥水，獲得了疾跑技能（第 1 位元 `0b0001`）。我們如何把疾跑技能「加進去」，而且保證絕對不會弄壞勇者原本已經擁有的護盾呢？
# 答案就是出動位元 OR：
# ```python
# status = status | 0b0001
# ```
# 原本是 1 的護盾依然保留是 1，原本是 0 的疾跑位元瞬間被點亮變成 1，狀態完美合體變成 `0b0101`！
# 學會用 `|` 合併狀態，你就能用最優雅的一行代碼操控複雜的遊戲技能樹！

# %%
# [2] Code 範例區：展示位元 OR（|）與狀態開關啟用
# 範例 1：逐位元 OR 運算
p = 0b1010  # 10
q = 0b0101  # 5
merged = p | q
print(merged)       # 印出 15（0b1111）
print(bin(merged))  # '0b1111'

# 範例 2：遊戲狀態合併（點亮新技能開關）
# 初始狀態：已擁有技能 A (0b0100)
hero_status = 0b0100
# 拾獲新技能 B (0b0010) 與 技能 C (0b0001)
hero_status = hero_status | 0b0010 | 0b0001
print(bin(hero_status))  # 印出 '0b111'（三個技能開關全部點亮！）

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 系統當前權限為 current_perm = 0b0100（十進位 4）。
# 管理員想要透過位元 OR 運算子，賦予使用者額外的 VIP 權限 mask_vip = 0b0010（十進位 2）。
# 請在空格處填入位元 OR 運算子 | 完成合併：
# ==========================================

current_perm = 0b0100
mask_vip = 0b0010

# 合併權限開關：
new_perm = current_perm ___ mask_vip
print(new_perm)  # 預期印出十進位整數 6（0b0110 = 6）

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定兩個整數 base_val 與 mask_val。
# 請使用位元 OR 運算子（|）計算兩者的位元合併結果，並使用 print() 印出其十進位數值。
#
# 【公開測試資料 1】
# base_val = 8, mask_val = 3
# 預期輸出：
# 11
# （說明：0b1000 | 0b0011 = 0b1011 = 11）
#
# 【公開測試資料 2】
# base_val = 16, mask_val = 15
# 預期輸出：
# 31
# （說明：0b10000 | 0b01111 = 0b11111 = 31）
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 智慧教室設備控制：
# 初始狀態為全部關閉 state = 0b0000。
# 投影機遮罩為 mask_proj = 0b0001，音響遮罩為 mask_audio = 0b0100，冷氣遮罩為 mask_ac = 0b1000。
# 請使用位元 OR 連續運算，一口氣將這三台設備全部啟動，
# 並使用兩行 print() 分別印出合併後的十進位值與二進位字串（bin）！
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🎭 2-7-3 位元 XOR（^）與開關翻轉／相同自消魔法
#
# 在單元 2-4 中，我們鄭重警告過大家：千萬不要把帽子脫字符號 `^` 當成次方運算！
# 今天，我們要正式為 `^` 舉行隆重的正名儀式——它的真名叫做「**位元互斥或運算子（Bitwise XOR）**」！
#
# 你可以把 XOR 想像成一對「**反骨叛逆雙胞胎**」：
# 只要兩個人「**意見不同（相異）**」，結果就是歡天喜地的 `1`；
# 如果兩個人「**意見一模一樣（相同）**」，結果就是無趣的 `0`！
#
# **位元 XOR 的運算真值表（相異為 1，相同為 0）**：
# * `1 ^ 0` $\rightarrow$ **`1`**（不同即為 1！）
# * `0 ^ 1` $\rightarrow$ **`1`**（不同即為 1！）
# * `1 ^ 1` $\rightarrow$ **`0`**（相同歸 0！）
# * `0 ^ 0` $\rightarrow$ **`0`**（相同歸 0！）
#
# **🎩 震撼競賽演算法的三大神級 XOR 魔法**：
# 1. **任何數字跟 0 做 XOR，保持原貌**：
#    $$x \text{ ^ } 0 = x$$
# 2. **任何數字跟自己做 XOR，自相消滅歸零（相同自消）**：
#    $$x \text{ ^ } x = 0$$
#    例如 `42 ^ 42` 算出來絕對是 `0`！在很多競技題目中，成對出現的數字只要全部連環 XOR 起來，一對一對的數字就會像俄羅斯方塊一樣全部自動消滅，最後留下來的就是那個「唯一落單的單身狗數字」！
# 3. **開關狀態快速翻轉（Toggle）**：
#    如果某個開關原本是 0，跟 1 做 XOR 就會變成 1；原本是 1，跟 1 做 XOR 就會翻轉回 0！不需要寫繁瑣的 `if-else`，一個 `^ 1` 瞬間完成開關切換！

# %%
# [2] Code 範例區：展示位元 XOR（^）的相異為 1、自相消滅與開關翻轉
# 範例 1：基本 XOR 比對（相異為 1，相同為 0）
a = 0b1010  # 10
b = 0b1100  # 12
print(bin(a ^ b))  # 印出 '0b110'（十進位 6）

# 範例 2：神級魔法——相同自相消滅歸 0
print(99 ^ 99)     # 印出 0！任何數與自己 XOR 必定消滅！
print(99 ^ 0)      # 印出 99！任何數與 0 XOR 保持原樣

# 範例 3：找單身狗數字（成對數字自動抵銷）
# 數列中有成對的 7 與 7，唯獨 15 是落單的
single = 7 ^ 15 ^ 7
print(single)      # 印出 15！（7 與 7 自消歸零，0 ^ 15 = 15）

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 遊戲中的隱形開關目前為關閉 stealth = 0。
# 想要使用位元 XOR 運算子（^）將其翻轉為開啟（1）。
# 請在空格處填入正確運算子：
# ==========================================

stealth = 0

# 開關翻轉：stealth ^ 1
stealth = stealth ___ 1
print(stealth)  # 預期印出 1（成功翻轉開啟）

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定兩個整數 x_val 與 y_val。
# 請使用位元 XOR 運算子（^）計算其相異比對數值，並使用 print() 印出結果。
#
# 【公開測試資料 1】
# x_val = 5, y_val = 3
# 預期輸出：
# 6
# （說明：0b101 ^ 0b011 = 0b110 = 6）
#
# 【公開測試資料 2】
# x_val = 15, y_val = 15
# 預期輸出：
# 0
# （說明：相同數字 XOR 自消歸零）
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 神秘數據解密：
# 有五個數值資料 [24, 55, 99, 55, 24]，其中 24 與 55 均成雙成對出現，唯獨 99 是唯一的關鍵金鑰。
# 請宣告變數並利用連續 XOR 運算（24 ^ 55 ^ 99 ^ 55 ^ 24），
# 親自驗證相同數值會全部自動抵銷，精準過濾出唯一的金鑰 99 並印出！
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ### 🎢 2-7-4 位元左移（<<）與右移（>>）——二進位滑梯與乘除倍增
#
# 最後登場的兩位成員，是位元世界最富動感的「位移雙兄弟」——**位元左移 `<<`** 與 **位元右移 `>>`**！
#
# 你可以把它們想像成排排坐的小朋友在玩「**二進位溜滑梯**」：
#
# **1. 左移運算子：`x << n`（向左滑推 $n$ 位）**
# 把數字的每一個位元全部往左邊推移 $n$ 格，右邊空出來的位元通通自動補上 `0`！
# * 在十進位中，數字後面補一個 0 代表「乘以 10」；
# * 在二進位中，數字後面補一個 0 代表「**乘以 2**」！
# 👉 **鐵則：向左移 1 位就是乘以 2；左移 $n$ 位就是乘以 $2^n$！**
# 例如：`5 << 1` 就是 $5 \times 2 = 10$；`5 << 2` 就是 $5 \times 4 = 20$！
#
# **2. 右移運算子：`x >> n`（向右滑推 $n$ 位）**
# 把數字的每一個位元全部往右邊推移 $n$ 格，最右邊掉落滑梯的位元直接丟棄！
# 👉 **鐵則：向右移 1 位剛好等價於「整除 2（`// 2`）」！**
# 例如：`19 >> 1` 就是 $19 // 2 = 9$；`19 >> 2` 就是 $19 // 4 = 4$！
#
# **🚀 頂尖競賽選手的提速日常**：
# 在未來的「二分搜尋法（Binary Search）」或快速冪演算法中，我們需要頻繁地將區間長度砍半。
# 頂尖選手會寫 `mid = (left + right) >> 1`，這在底層直接調動 CPU 的位移暫存器，比執行整除除法更快、更具極客風範！

# %%
# [2] Code 範例區：展示位元左移 << 與右移 >> 的倍增與減半效果
# 範例 1：左移 << 相當於乘以 2 的次方
val = 5
print(val << 1)  # 5 * 2 = 10
print(val << 2)  # 5 * 4 = 20
print(val << 3)  # 5 * 8 = 40

# 範例 2：右移 >> 相當於整除 2 的次方（去尾整除）
num = 19
print(num >> 1)  # 19 // 2 = 9
print(num >> 2)  # 19 // 4 = 4
print(num >> 3)  # 19 // 8 = 2

# %%
# ==========================================
# [3] Code 填空題
# 任務說明：
# 想要將數值 base = 7 快速擴增為原本的 4 倍（即左移 2 位）。
# 請在空格處填入位元左移運算子 <<：
# ==========================================

base = 7

# 左移 2 位（乘以 4）：
quadruple = base ___ 2
print(quadruple)  # 預期印出 28（7 * 4 = 28）

# %%
# ==========================================
# [4] Code 練習題
# 任務說明：
# 給定一個初始整數 sample_n。
# 請依序使用兩行 print() 分別印出：
# 1. 該數左移 1 位（sample_n << 1，即翻倍）的結果。
# 2. 該數右移 1 位（sample_n >> 1，即減半）的結果。
#
# 【公開測試資料 1】
# sample_n = 12
# 預期輸出：
# 24
# 6
#
# 【公開測試資料 2】
# sample_n = 25
# 預期輸出：
# 50
# 12
# ==========================================
# 請在下方撰寫你的程式碼並執行測試：

# %%
# ==========================================
# [5] Code 挑戰題
# 任務說明：
# （本題為自由挑戰題，無公開測資，請依題目情境自行思考並撰寫完整程式碼）
# 二分搜尋折半演算法先導練習：
# 搜尋區間左端點 left = 10，右端點 right = 25。
# 1. 請使用小括號將 left 與 right 加總：(left + right)。
# 2. 使用位元右移運算子 >> 1 求得區間正中間的整數中點 mid。
# 3. 印出 mid 的數值（預期 (10 + 25) >> 1 = 35 // 2 = 17）！
# ==========================================
# 請在下方撰寫你的程式碼：

# %% [markdown]
# ---
# ### 🏆 恭喜完成第二章全章大封頂：位元加速宗師徽章！
#
# 太震撼、太不可思議了！你已經徹底攻克了《PythAPCS123》全書難度最高、最底層的「第二章 資料型態與數值 / 位元運算」全部 7 個單元！
# 今天你在位元世界中學到了這套傳奇武器：
# 1. **位元 AND（&）**：`x & 1` 單一週期極速判定奇偶數，取代模除 `% 2` 避免超時 TLE！
# 2. **位元 OR（|）**：狀態遮罩點亮神器，在不干擾其他狀態的前提下精準開啟特權開關。
# 3. **位元 XOR（^）**：脫字符號真面目，相異為 1、相同為 0，自消魔法 `x ^ x = 0` 快速找出單身狗落單數字！
# 4. **左移與右移（<<, >>）**：二進位滑梯，左移一位翻倍（`* 2`）、右移一位折半（`// 2`），競賽選手的極致提速手法。
#
# 🎉 **第二章全面通關！**
# 👉 **下一關預告**：在第三章的 **單元 3-1** 中，我們要來進入「**型態轉換與內建數學函數**」，深入探索數值與文字強制轉型（`int()`, `float()`, `str()`），學習如何將數字轉成文字進行字串反轉與字元拆解！敬請期待！
